# %%
from openbb import obb
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
# Financial statement functions are grouped under the obb.equity.fundamental module.

# %%
obb.equity.fundamental.balance("AAPL", provider="fmp", limit=4).to_df()
# Out:
#   period_ending fiscal_period  fiscal_year filing_date       accepted_date  \
# 0    2023-09-30            FY         2023  2023-11-03 2023-11-02 18:08:27
# 1    2022-09-24            FY         2022  2022-10-28 2022-10-27 18:01:14
# 2    2021-09-25            FY         2021  2021-10-29 2021-10-28 18:04:28
# 3    2020-09-26            FY         2020  2020-10-30 2020-10-29 18:06:25
#
#   reported_currency  cash_and_cash_equivalents  short_term_investments  \
# 0               USD               2.996500e+10            3.159000e+10
# 1               USD               2.364600e+10            2.465800e+10
# 2               USD               3.494000e+10            2.769900e+10
# 3               USD               3.801600e+10            5.292700e+10
#
#    cash_and_short_term_investments  net_receivables  ...  \
# 0                     6.155500e+10     6.098500e+10  ...
# 1                     4.830400e+10     6.093200e+10  ...
# 2                     6.263900e+10     5.150600e+10  ...
# 3                     9.094300e+10     3.744500e+10  ...
#
#    accumulated_other_comprehensive_income  total_common_equity  \
# 0                           -1.145200e+10         6.214600e+10
# 1                           -1.110900e+10         5.067200e+10
# 2                            1.630000e+08         6.309000e+10
# 3                           -4.060000e+08         6.533900e+10
#
#    total_equity_non_controlling_interests  \
# 0                            6.214600e+10
# 1                            5.067200e+10
# 2                            6.309000e+10
# 3                            6.533900e+10
#
#    total_liabilities_and_shareholders_equity  \
# 0                               3.525830e+11
# 1                               3.527550e+11
# 2                               3.510020e+11
# 3                               3.238880e+11
#
#    total_liabilities_and_total_equity  total_investments    total_debt  \
# 0                        3.525830e+11       3.159000e+10  1.110880e+11
# 1                        3.527550e+11       1.454630e+11  1.200690e+11
# 2                        3.510020e+11       1.555760e+11  1.247190e+11
# 3                        3.238880e+11       1.538140e+11  1.124360e+11
#
#        net_debt                                               link  \
# 0  8.112300e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 1  9.642300e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 2  8.977900e+10  https://www.sec.gov/Archives/edgar/data/320193...
# 3  7.442000e+10  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                           final_link
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
#
# [4 rows x 39 columns]

# %%
obb.equity.fundamental.income("AAPL", provider="fmp", limit=4).to_df()
# Out:
#   period_ending fiscal_period  fiscal_year filing_date       accepted_date  \
# 0    2023-09-30            FY         2023  2023-11-03 2023-11-02 18:08:27
# 1    2022-09-24            FY         2022  2022-10-28 2022-10-27 18:01:14
# 2    2021-09-25            FY         2021  2021-10-29 2021-10-28 18:04:28
# 3    2020-09-26            FY         2020  2020-10-30 2020-10-29 18:06:25
#
#   reported_currency       revenue  cost_of_revenue  gross_profit  \
# 0               USD  3.832850e+11     2.141370e+11  1.691480e+11
# 1               USD  3.943280e+11     2.235460e+11  1.707820e+11
# 2               USD  3.658170e+11     2.129810e+11  1.528360e+11
# 3               USD  2.745150e+11     1.695590e+11  1.049560e+11
#
#    gross_profit_margin  ...  pre_tax_income_margin  income_tax_expense  \
# 0             0.441311  ...               0.296740        1.674100e+10
# 1             0.433096  ...               0.302040        1.930000e+10
# 2             0.417794  ...               0.298529        1.452700e+10
# 3             0.382332  ...               0.244398        9.680000e+09
#
#    consolidated_net_income  net_income_margin  basic_earnings_per_share  \
# 0             9.699500e+10           0.253062                      6.16
# 1             9.980300e+10           0.253096                      6.15
# 2             9.468000e+10           0.258818                      5.67
# 3             5.741100e+10           0.209136                      3.31
#
#    diluted_earnings_per_share  weighted_average_basic_shares_outstanding  \
# 0                        6.13                               1.574423e+10
# 1                        6.11                               1.621596e+10
# 2                        5.61                               1.670127e+10
# 3                        3.28                               1.735212e+10
#
#    weighted_average_diluted_shares_outstanding  \
# 0                                 1.581255e+10
# 1                                 1.632582e+10
# 2                                 1.686492e+10
# 3                                 1.752821e+10
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                           final_link
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
#
# [4 rows x 34 columns]

# %%
llm = ChatOpenAI(openai_api_key=os.getenv("OPENAI_API_KEY"))

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x13bc651d0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x13c84dbd0>, openai_api_key='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', openai_proxy='')

# %%
llm.invoke("Who is Elon Musk?")
# Out:
# AIMessage(content="Elon Musk is a prominent entrepreneur and business magnate. He was born on June 28, 1971, in Pretoria, South Africa. Musk is the CEO and lead designer of SpaceX, CEO and product architect of Tesla, Inc., CEO of Neuralink, and founder of The Boring Company. He has also been involved in various other ventures, including SolarCity and PayPal.\n\nElon Musk is widely recognized for his vision and efforts in advancing sustainable energy and space exploration. SpaceX, under Musk's leadership, has made significant advancements in rocket technology and has successfully launched numerous missions, including the first privately funded spacecraft to reach orbit. Tesla, Inc., founded by Musk, is a leading electric vehicle manufacturer that aims to accelerate the world's transition to sustainable transportation.\n\nMusk is known for his ambitious goals, such as colonizing Mars and creating a high-speed transportation system known as the Hyperloop. He is often seen as a visionary and has been named one of the most influential people in the world by various publications.")

# %%
from openbb_agents.agent import openbb_agent
from openbb_agents.tools import map_openbb_routes_to_langchain_tools
openbb_tools = map_openbb_routes_to_langchain_tools(
    openbb_commands_root = [
        "/equity/fundamental",
    ]
)

# %%
openbb_tools
# Out:
# [StructuredTool(name='/equity/fundamental/multiples', description='Equity Valuation Multiples. Valuation multiples for a stock ticker.\nThe following data is available in the output:\n\nsymbol, revenue per share ttm, net income per share ttm, operating cash flow per share ttm, free cash flow per share ttm, cash per share ttm, book value per share ttm, tangible book value per share ttm, shareholders equity per share ttm, interest debt per share ttm, market cap ttm, enterprise value ttm, pe ratio ttm, price to sales ratio ttm, pocf ratio ttm, pfcf ratio ttm, pb ratio ttm, ptb ratio ttm, ev to sales ttm, enterprise value over ebitda ttm, ev to operating cash flow ttm, ev to free cash flow ttm, earnings yield ttm, free cash flow yield ttm, debt to equity ttm, debt to assets ttm, net debt to ebitda ttm, current ratio ttm, interest coverage ttm, income quality ttm, dividend yield ttm, dividend yield percentage ttm, dividend to market cap ttm, dividend per share ttm, payout ratio ttm, sales general and administrative to revenue ttm, research and development to revenue ttm, intangibles to total assets ttm, capex to operating cash flow ttm, capex to revenue ttm, capex to depreciation ttm, stock based compensation to revenue ttm, graham number ttm, roic ttm, return on tangible assets ttm, graham net net ttm, working capital ttm, tangible asset value ttm, net current asset value ttm, invested capital ttm, average receivables ttm, average payables ttm, average inventory ttm, days sales outstanding ttm, days payables outstanding ttm, days of inventory on hand ttm, receivables turnover ttm, payables turnover ttm, inventory turnover ttm, roe ttm, capex per share ttm', args_schema=<class 'pydantic.v1.main./equity/fundamental/multiplesInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f3eb920>, run=<function BaseTool.run at 0x13f3eb7e0>),
#  StructuredTool(name='/equity/fundamental/balance', description='Balance Sheet. Balance sheet statement.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year', args_schema=<class 'pydantic.v1.main./equity/fundamental/balanceInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13ad6f6a0>, run=<function BaseTool.run at 0x13f3eaca0>),
#  StructuredTool(name='/equity/fundamental/balance_growth', description='Balance Sheet Statement Growth. Information about the growth of the company balance sheet.\nThe following data is available in the output:\n\nsymbol, date, period, growth cash and cash equivalents, growth short term investments, growth cash and short term investments, growth net receivables, growth inventory, growth other current assets, growth total current assets, growth property plant equipment net, growth goodwill, growth intangible assets, growth goodwill and intangible assets, growth long term investments, growth tax assets, growth other non current assets, growth total non current assets, growth other assets, growth total assets, growth account payables, growth short term debt, growth tax payables, growth deferred revenue, growth other current liabilities, growth total current liabilities, growth long term debt, growth deferred revenue non current, growth deferrred tax liabilities non current, growth other non current liabilities, growth total non current liabilities, growth other liabilities, growth total liabilities, growth common stock, growth retained earnings, growth accumulated other comprehensive income loss, growth othertotal stockholders equity, growth total stockholders equity, growth total liabilities and stockholders equity, growth total investments, growth total debt, growth net debt', args_schema=<class 'pydantic.v1.main./equity/fundamental/balance_growthInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f3eae80>, run=<function BaseTool.run at 0x13f409300>),
#  StructuredTool(name='/equity/fundamental/cash', description='Cash Flow Statement. Information about the cash flow statement.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year', args_schema=<class 'pydantic.v1.main./equity/fundamental/cashInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f3ebe20>, run=<function BaseTool.run at 0x13f409580>),
#  StructuredTool(name='/equity/fundamental/reported_financials', description='Financial statements, as-reported.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year', args_schema=<class 'pydantic.v1.main./equity/fundamental/reported_financialsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4096c0>, run=<function BaseTool.run at 0x13f40bc40>),
#  StructuredTool(name='/equity/fundamental/cash_growth', description='Cash Flow Statement Growth. Information about the growth of the company cash flow statement.\nThe following data is available in the output:\n\nsymbol, date, period, growth net income, growth depreciation and amortization, growth deferred income tax, growth stock based compensation, growth change in working capital, growth accounts receivables, growth inventory, growth accounts payables, growth other working capital, growth other non cash items, growth net cash provided by operating activities, growth investments in property plant and equipment, growth acquisitions net, growth purchases of investments, growth sales maturities of investments, growth other investing activities, growth net cash used for investing activities, growth debt repayment, growth common stock issued, growth common stock repurchased, growth dividends paid, growth other financing activities, growth net cash used provided by financing activities, growth effect of forex changes on cash, growth net change in cash, growth cash at end of period, growth cash at beginning of period, growth operating cash flow, growth capital expenditure, growth free cash flow', args_schema=<class 'pydantic.v1.main./equity/fundamental/cash_growthInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40b380>, run=<function BaseTool.run at 0x13f40aa20>),
#  StructuredTool(name='/equity/fundamental/dividends', description='Historical Dividends. Historical dividends data for a given company.\nThe following data is available in the output:\n\ndate, dividend', args_schema=<class 'pydantic.v1.main./equity/fundamental/dividendsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40b6a0>, run=<function BaseTool.run at 0x13f40a200>),
#  StructuredTool(name='/equity/fundamental/historical_eps', description='Historical earnings-per-share for a given company.\nThe following data is available in the output:\n\ndate, symbol, announce time, eps actual, eps estimated', args_schema=<class 'pydantic.v1.main./equity/fundamental/historical_epsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40be20>, run=<function BaseTool.run at 0x13f40ba60>),
#  StructuredTool(name='/equity/fundamental/employee_count', description='Historical Employees. Historical number of employees.\nThe following data is available in the output:\n\nsymbol, cik, acceptance time, period of report, company name, form type, filing date, employee count, source', args_schema=<class 'pydantic.v1.main./equity/fundamental/employee_countInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40a7a0>, run=<function BaseTool.run at 0x13f40b9c0>),
#  StructuredTool(name='/equity/fundamental/search_attributes', description='Search Intrinio data tags.\nThe following data is available in the output:\n\nid, name, tag, statement code, statement type, parent name, sequence, factor, transaction, type, unit', args_schema=<class 'pydantic.v1.main./equity/fundamental/search_attributesInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40b4c0>, run=<function BaseTool.run at 0x13f409da0>),
#  StructuredTool(name='/equity/fundamental/latest_attributes', description='Fetch the latest value of a data tag from Intrinio.\nThe following data is available in the output:\n\nvalue', args_schema=<class 'pydantic.v1.main./equity/fundamental/latest_attributesInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40b100>, run=<function BaseTool.run at 0x13f408fe0>),
#  StructuredTool(name='/equity/fundamental/historical_attributes', description='Fetch the historical values of a data tag from Intrinio.\nThe following data is available in the output:\n\ndate, value', args_schema=<class 'pydantic.v1.main./equity/fundamental/historical_attributesInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40b920>, run=<function BaseTool.run at 0x13f40a5c0>),
#  StructuredTool(name='/equity/fundamental/income', description="Income Statement. Report on a company's financial performance.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year", args_schema=<class 'pydantic.v1.main./equity/fundamental/incomeInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f40ad40>, run=<function BaseTool.run at 0x13f4b2ac0>),
#  StructuredTool(name='/equity/fundamental/income_growth', description='Income Statement Growth. Information about the growth of the company income statement.\nThe following data is available in the output:\n\nsymbol, date, period, growth revenue, growth cost of revenue, growth gross profit, growth gross profit ratio, growth research and development expenses, growth general and administrative expenses, growth selling and marketing expenses, growth other expenses, growth operating expenses, growth cost and expenses, growth interest expense, growth depreciation and amortization, growth ebitda, growth ebitda ratio, growth operating income, growth operating income ratio, growth total other income expenses net, growth income before tax, growth income before tax ratio, growth income tax expense, growth net income, growth net income ratio, growth eps, growth eps diluted, growth weighted average shs out, growth weighted average shs out dil', args_schema=<class 'pydantic.v1.main./equity/fundamental/income_growthInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13e717ec0>, run=<function BaseTool.run at 0x13f4b3d80>),
#  StructuredTool(name='/equity/fundamental/metrics', description='Key Metrics. Key metrics for a given company.\nThe following data is available in the output:\n\nsymbol, market cap, pe ratio', args_schema=<class 'pydantic.v1.main./equity/fundamental/metricsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b3600>, run=<function BaseTool.run at 0x13f4b3ba0>),
#  StructuredTool(name='/equity/fundamental/management', description='Key Executives. Key executives for a given company.\nThe following data is available in the output:\n\ntitle, name, pay, currency pay, gender, year born, title since', args_schema=<class 'pydantic.v1.main./equity/fundamental/managementInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b3ce0>, run=<function BaseTool.run at 0x13f4b3880>),
#  StructuredTool(name='/equity/fundamental/management_compensation', description='Get Executive Compensation. Information about the executive compensation for a given company.\nThe following data is available in the output:\n\nsymbol, cik, filing date, accepted date, name and position, year, salary, bonus, stock award, incentive plan compensation, all other compensation, total, url', args_schema=<class 'pydantic.v1.main./equity/fundamental/management_compensationInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b3a60>, run=<function BaseTool.run at 0x13f4b2480>),
#  StructuredTool(name='/equity/fundamental/overview', description='Company Overview. General information about a company.\nThe following data is available in the output:\n\nsymbol, price, beta, vol avg, mkt cap, last div, range, changes, company name, currency, cik, isin, cusip, exchange, exchange short name, industry, website, description, ceo, sector, country, full time employees, phone, address, city, state, zip, dcf diff, dcf, image, ipo date, default image, is etf, is actively trading, is adr, is fund', args_schema=<class 'pydantic.v1.main./equity/fundamental/overviewInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b2520>, run=<function BaseTool.run at 0x13f4b2160>),
#  StructuredTool(name='/equity/fundamental/ratios', description='Extensive set of ratios over time. Financial ratios for a given company.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year', args_schema=<class 'pydantic.v1.main./equity/fundamental/ratiosInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b2200>, run=<function BaseTool.run at 0x13f4b1f80>),
#  StructuredTool(name='/equity/fundamental/revenue_per_geography', description='Revenue Geographic. Geographic revenue data.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year, filing date, geographic segment', args_schema=<class 'pydantic.v1.main./equity/fundamental/revenue_per_geographyInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b2020>, run=<function BaseTool.run at 0x13f4b0ea0>),
#  StructuredTool(name='/equity/fundamental/revenue_per_segment', description='Revenue Business Line. Business line revenue data.\nThe following data is available in the output:\n\nperiod ending, fiscal period, fiscal year, filing date, business line', args_schema=<class 'pydantic.v1.main./equity/fundamental/revenue_per_segmentInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b14e0>, run=<function BaseTool.run at 0x13f4b11c0>),
#  StructuredTool(name='/equity/fundamental/filings', description='Company Filings. Company filings data.\nThe following data is available in the output:\n\nfiling date, accepted date, symbol, cik, report type, filing url, report url', args_schema=<class 'pydantic.v1.main./equity/fundamental/filingsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b0720>, run=<function BaseTool.run at 0x13f4b02c0>),
#  StructuredTool(name='/equity/fundamental/historical_splits', description='Historical Splits. Historical splits data.\nThe following data is available in the output:\n\ndate, label, numerator, denominator', args_schema=<class 'pydantic.v1.main./equity/fundamental/historical_splitsInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b0b80>, run=<function BaseTool.run at 0x13f4b1ee0>),
#  StructuredTool(name='/equity/fundamental/transcript', description='Earnings Call Transcript. Earnings call transcript for a given company.\nThe following data is available in the output:\n\nsymbol, quarter, year, date, content', args_schema=<class 'pydantic.v1.main./equity/fundamental/transcriptInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b0c20>, run=<function BaseTool.run at 0x13f4b1da0>),
#  StructuredTool(name='/equity/fundamental/trailing_dividend_yield', description='Trailing 1yr dividend yield.\nThe following data is available in the output:\n\ndate, trailing dividend yield', args_schema=<class 'pydantic.v1.main./equity/fundamental/trailing_dividend_yieldInputModel'>, handle_tool_error=True, func=<function return_results.<locals>.wrapper_func at 0x13f4b0fe0>, run=<function BaseTool.run at 0x13f4b00e0>)]
